# %% [markdown]
# <div style="direction: rtl; text-align: right; font-family: inherit; background: linear-gradient(135deg, #1a2634 0%, #2c3e50 60%, #34586e 100%); border-radius: 12px; padding: 44px 34px; color: #ffffff; box-shadow: 0 4px 18px rgba(44,62,80,0.20);">
# <div style="width: 56px; height: 5px; background: #3498db; border-radius: 3px; margin-bottom: 18px;"></div>
# <h1 style="margin: 0; font-size: 2.4em; font-weight: 800; line-height: 1.25; color: #ffffff;"> פרויקט</h1>
# <div style="font-size: 1.25em; font-weight: 300; color: #9fd3f2; margin-top: 6px;">סדנה במדעי הנתונים</div>
# <div style="height: 1px; background: rgba(255,255,255,0.18); margin: 28px 0 22px 0;"></div>
# <div style="font-size: 1.05em; line-height: 2.1;">
# <div><span style="color: #9fd3f2; font-weight: 700; display: inline-block; min-width: 90px;">סמסטר</span>2026ג.</div>
# <div><span style="color: #9fd3f2; font-weight: 700; display: inline-block; min-width: 90px;">מגישים</span>   מקסים סובולב ואסתר אזולאי.</div>
# <div><span style="color: #9fd3f2; font-weight: 700; display: inline-block; min-width: 90px;">מנחה</span>ד"ר זאב קליוזנר.</div>
# </div>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: #ffffff; border: 1px solid #e1e8ed; border-radius: 12px; padding: 24px 26px;">
# <div style="width: 40px; height: 4px; background: #3498db; border-radius: 3px; margin-bottom: 12px;"></div>
# <h3 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; font-size: 1.35em; font-weight: 700; color: #2c3e50;">רעיון הפרויקט</h3>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0; line-height: 1.8; color: #2c3e50;">זיהוי דרכונים בתוך מסמכים דיגיטליים, וחילוץ נתוני המפתח שבהם, באמצעות טכניקות של למידת מכונה ולמידה עמוקה, בצורה מהירה וללא דרישות גבוהות של משאבי מחשוב ועלויות.</div>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: #ffffff; border: 1px solid #e1e8ed; border-radius: 12px; padding: 24px 26px;">
# <div style="width: 40px; height: 4px; background: #3498db; border-radius: 3px; margin-bottom: 12px;"></div>
# <h3 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 8px 0; font-size: 1.35em; font-weight: 700; color: #2c3e50;">מטרת הפרויקט</h3>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 16px 0; line-height: 1.8; color: #5d6d7e;">פיתוח מערכת העונה לדרישות הבאות:</div>
# <div style="direction: rtl !important; text-align: right !important; background: #f7fafc; border-right: 4px solid #3498db; border-radius: 8px; padding: 12px 16px; margin-bottom: 10px;">
# <div style="direction: rtl !important; text-align: right !important; font-weight: 700; color: #2471a3; margin-bottom: 5px;">זיהוי נוכחות דרכון</div>
# <div style="direction: rtl !important; text-align: right !important; line-height: 1.75; color: #2c3e50;">המשימה המרכזית: לזהות האם מסמך מכיל תצלום דרכון החושף פרטים אישיים.</div>
# </div>
# <div style="direction: rtl !important; text-align: right !important; background: #f7fafc; border-right: 4px solid #3498db; border-radius: 8px; padding: 12px 16px; margin-bottom: 10px;">
# <div style="direction: rtl !important; text-align: right !important; font-weight: 700; color: #2471a3; margin-bottom: 5px;">הצפת נתונים רגישים</div>
# <div style="direction: rtl !important; text-align: right !important; line-height: 1.75; color: #2c3e50;">לאחר הזיהוי, חילוץ והצפה של השדות הרגישים מתוך הדרכון, כגון: <span style="color: #c0392b; font-weight: 700;">שם מלא, מספר דרכון, אזרחות, תאריך לידה ותאריך תפוגה</span>.</div>
# </div>
# <div style="direction: rtl !important; text-align: right !important; background: #f7fafc; border-right: 4px solid #3498db; border-radius: 8px; padding: 12px 16px; margin-bottom: 10px;">
# <div style="direction: rtl !important; text-align: right !important; font-weight: 700; color: #2471a3; margin-bottom: 5px;">עמידות ורובוסטיות</div>
# <div style="direction: rtl !important; text-align: right !important; line-height: 1.75; color: #2c3e50;">התמודדות עם תנאים מאתגרים כגון מסמכים המצולמים בזווית, באיכות נמוכה, או כאלה המכילים רעש ומידע נוסף ברקע, לצד יכולת ריצה בסביבה דלת משאבים.</div>
# </div>
# <div style="direction: rtl !important; text-align: right !important; background: #f7fafc; border-right: 4px solid #3498db; border-radius: 8px; padding: 12px 16px;">
# <div style="direction: rtl !important; text-align: right !important; font-weight: 700; color: #2471a3; margin-bottom: 5px;">מדדי הצלחה</div>
# <div style="direction: rtl !important; text-align: right !important; line-height: 1.75; color: #2c3e50;">המדד המרכזי הוא דיוק בזיהוי נוכחות דרכון במסמך. בנוסף נבחן שיעור השדות הרגישים שחולצו נכון מתוך אלה שקיימים בדרכון שזוהה.</div>
# </div>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: #ffffff; border: 1px solid #e1e8ed; border-radius: 12px; padding: 24px 26px;">
# <div style="width: 40px; height: 4px; background: #3498db; border-radius: 3px; margin-bottom: 12px;"></div>
# <h3 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; font-size: 1.35em; font-weight: 700; color: #2c3e50;">מוטיבציה עסקית וטכנולוגית</h3>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; line-height: 1.8; color: #2c3e50;">ארגונים רבים נדרשים לעבד מסמכים מזהים המכילים <b>מידע אישי ורגיש</b>, ובחלק ניכר מהמקרים קליטת הנתונים ואימות הזהות עדיין מתבצעים ידנית. תהליך זה איטי, מועד לטעויות, וחושף מידע פרטי לעיניים אנושיות שלא לצורך.</div>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; line-height: 1.8; color: #2c3e50;">בנוסף, ריבוי המסמכים העוברים בין ארגונים חושף אותם לאתגרים בשני מישורים: באבטחת המידע, הנפגעת עקב דליפת מסמכים רגישים; וברגולציה, המחייבת פעמים רבות מערכות כבדות ויקרות כדי לעמוד בתקן הנדרש.</div>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 16px 0; line-height: 1.8; color: #2c3e50;">הצורך במערכת אוטומטית לחילוץ נתונים מדרכונים קיים בענפים רבים, בהם תיירות, בנקאות ופיננסים, ביטוח וקליטת עובדים. אולם הפתרונות הזמינים כיום מציבים חסמים בפני חלק מהעסקים.</div>
# <div style="direction: rtl !important; text-align: right !important; background: #f7fafc; border-right: 4px solid #3498db; border-radius: 8px; padding: 12px 16px;">
# <div style="direction: rtl !important; text-align: right !important; font-weight: 700; color: #2471a3; margin-bottom: 8px;">הפער בשוק</div>
# <div style="direction: rtl !important; text-align: right !important; line-height: 1.75; color: #2c3e50;">הפתרונות הזמינים נחלקים לשתי קטגוריות, וכל אחת מהן מציבה חסם משלה:
# <ol style="margin-top: 8px; margin-bottom: 0; padding-right: 24px;">
# <li style="margin-bottom: 8px;"><b>שירותי ענן:</b> מחייבים שליחת תמונות של מסמכים מזהים לשרתים חיצוניים, ולפיכך אינם מתאימים לארגונים הנדרשים לשמור מידע אישי בתוך הארגון.</li>
# <li><b>מערכות מקומיות כבדות:</b> מבוססות על מודלים גדולים להבנת מסמכים, ומחייבות חומרה ייעודית, בראש ובראשונה מעבד גרפי, כדי לעבד מסמך בזמן המתאים לשימוש תפעולי.</li>
# </ol>
# </div>
# </div>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: #ffffff; border: 1px solid #e1e8ed; border-radius: 12px; padding: 24px 26px;">
# <div style="width: 40px; height: 4px; background: #3498db; border-radius: 3px; margin-bottom: 12px;"></div>
# <h3 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; font-size: 1.35em; font-weight: 700; color: #2c3e50;">אילוץ תכנוני: פתרון מקומי מבוסס CPU</h3>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; line-height: 1.8; color: #2c3e50;">מתוך שני החסמים שתוארו לעיל נגזר אילוץ תכנוני מרכזי: המערכת תפעל באופן מקומי בלבד, ועל גבי מעבד מחשב סטנדרטי, ללא תלות בשירותי ענן חיצוניים ובלא חומרה ייעודית. אילוץ זה נועד להבטיח שהפתרון יישאר זול ופשוט להטמעה.</div>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0; line-height: 1.8; color: #2c3e50;">אילוץ זה מתנגש עם דרישת העמידות: ככל שהמערכת נדרשת להתמודד עם אתגרי איכות וצורת סריקת הדרכון, כך גדלה הנטייה לפתרונות עתירי חישוב. התנגשות זו מלווה את הפרויקט לכל אורכו, והיא שמכתיבה את סדר הבחינה של הגישות השונות.</div>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: linear-gradient(135deg, #1a2634 0%, #2c3e50 60%, #34586e 100%); border-radius: 12px; padding: 32px 34px; color: #ffffff; box-shadow: 0 4px 18px rgba(44,62,80,0.20);">
# <div style="direction: ltr !important; text-align: left !important; font-family: inherit; font-size: 0.82em; font-weight: 700; letter-spacing: 1.5px; text-transform: uppercase; color: #9fd3f2; margin-bottom: 6px;">Baseline Evaluation</div>
# <div style="width: 56px; height: 5px; background: #3498db; border-radius: 3px; margin-bottom: 16px;"></div>
# <h2 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0; font-size: 1.9em; font-weight: 800; color: #ffffff;">שלב ראשוני- הערכת קו בסיס</h2>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: #ffffff; border: 1px solid #e1e8ed; border-radius: 12px; padding: 24px 26px;">
# <div style="width: 40px; height: 4px; background: #3498db; border-radius: 3px; margin-bottom: 12px;"></div>
# <h3 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; font-size: 1.35em; font-weight: 700; color: #2c3e50;">הגישה הנבחנת בשלב זה: מודל מבוסס OCR וחוקיות (Regex)</h3>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; line-height: 1.8; color: #2c3e50;">הגישה הראשונה שנבחנת מתבססת על תהליך דו-שלבי: תחילה הפעלת מנוע זיהוי תווים אופטי (OCR) לחילוץ הטקסט מהתמונה, ולאחר מכן יישום של ביטויים רגולריים (Regex) לאיתור תבניות טקסט ייחודיות המאפיינות דרכונים, ובראשן אזור ה-MRZ המוגדר בתקן בינלאומי.</div>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0; line-height: 1.8; color: #2c3e50;">הבחירה להתחיל בגישה זו נובעת מיעילותה: היא אינה דורשת אימון מראש ומאפשרת ריצה חלקה על מעבד סטנדרטי, ובכך עונה על אילוצי הפרויקט. בנוסף היא משמשת אותנו כקו בסיס, כלומר נקודת ייחוס ברורה לביצועי המערכת. לאחר בחינת תוצאות השלב וקבלת אינדיקציה היכן הגישה נכשלת, נוכל להתקדם בצורה מבוססת לגישה מורכבת יותר.</div>
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; background: #ffffff; border: 1px solid #e1e8ed; border-radius: 12px; padding: 24px 26px;">
# <div style="width: 40px; height: 4px; background: #3498db; border-radius: 3px; margin-bottom: 12px;"></div>
# <h3 style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; font-size: 1.35em; font-weight: 700; color: #2c3e50;">שלב ראשוני: הערכת קו בסיס</h3>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; line-height: 1.8; color: #2c3e50;">לצורך בחינת גבולות הגישה והערכת קו הבסיס, בנינו מאגר מסמכים סינתטי בפורמטים נפוצים (Word ו-PDF). מאגר זה תוכנן במטרה לדמות תרחישי מציאות מגוונים: הוא מבוסס על תצלומי דרכונים פיקטיביים ממאגר נתונים פתוח, כאשר חלקם שולבו במסמכים בתצוגה ברורה ותקנית, ואילו חלקם שובשו במכוון באמצעות טשטוש, שינוי זווית, רעש או פיקסול. מניפולציות אלו נועדו לייצר מקרי קצה שמאתגרים את המערכת ומשמשים כמבחן מאמץ לאלגוריתם הזיהוי.</div>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0 0 14px 0; line-height: 1.8; color: #2c3e50;">כדי להתמודד עם האתגר שמציבים הפורמטים השונים, בחרנו לנרמל את המסמכים תחילה לתמונות, כאשר כל עמוד מהווה תמונה. תהליך המרה זה מבטיח שכל שלבי העיבוד הבאים יפעלו על קלט חזותי אחיד, ללא תלות בפורמט הקובץ המקורי.</div>
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit; margin: 0; line-height: 1.8; color: #2c3e50;">על גבי התמונות המנורמלות מופעל מנוע ה-OCR (Optical Character Recognition), טכנולוגיה המנתחת את הפיקסלים שבתמונה, מזהה בהם צורות של אותיות ומספרים, ומתרגמת אותם לטקסט דיגיטלי. זהו הגישור ההכרחי בין הנתונים החזותיים לבין שלב הזיהוי באמצעות Regex, הדורש טקסט קריא כדי לאתר את התבניות ולהכריע האם קיים דרכון בעמוד.</div>
# </div>
