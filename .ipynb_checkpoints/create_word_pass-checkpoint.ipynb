# %%
from docx import Document
from docx.shared import Cm
import cv2
import random


image1 = 'passport1.jpg'
image2 = 'passport2.jpg'


img_to_rotate = cv2.imread(image1)
cv2.imwrite('passport_rotated_90.jpg', cv2.rotate(img_to_rotate, cv2.ROTATE_90_CLOCKWISE))
cv2.imwrite('passport_upside_down.jpg', cv2.rotate(img_to_rotate, cv2.ROTATE_180))

normal_images = [image1, image2]
edge_case_images = ['passport_rotated_90.jpg', 'passport_upside_down.jpg']

# Some dummy texts to simulate real forms
dummy_texts = [
    "Please find the attached identification document for the applicant.",
    "Confidential document. Do not share without authorized permission.",
    "The following scan was provided during the registration process.",
    "Applicant submitted the passport copy for identity verification.",
    "Verify the extracted fields from the image below against the database."
]

def create_randomized_doc(doc_name, image_list):
    doc = Document()
    
    # Random heading
    doc.add_heading(f'Application Form - {random.randint(1000, 9999)}', level=1)
    
    # Random introductory text
    doc.add_paragraph(random.choice(dummy_texts))
    
   
    if random.choice([True, False]):
        table = doc.add_table(rows=2, cols=2)
        table.cell(0, 0).text = 'Client ID'
        table.cell(0, 1).text = str(random.randint(100000, 999999))
        table.cell(1, 0).text = 'Validation Status'
        table.cell(1, 1).text = 'Pending'
        doc.add_paragraph("") # empty line
        
    doc.add_paragraph("--- DOCUMENT SCAN BEGINS ---")
    
    # Add random sized image (between 8 and 15 cm)
    chosen_image = random.choice(image_list)
    random_width = random.uniform(8.0, 15.0)
    doc.add_picture(chosen_image, width=Cm(random_width))
    
    doc.add_paragraph("--- DOCUMENT SCAN ENDS ---")
    doc.add_paragraph("Please ensure all data points are extracted properly by the OCR engine.")
    
    doc.save(doc_name)



# Create 10 Word documents with normal passports
for i in range(1, 11):
    create_randomized_doc(f'Word_Normal_Doc_{i}.docx', normal_images)
    
# Create 5 edge case Word documents
for i in range(11, 16):
    create_randomized_doc(f'Word_Edge_Case_{i}.docx', edge_case_images)
    
print("Process completed! 15 Word documents were created.")
# Out:
# Process completed! 15 Word documents were created.
