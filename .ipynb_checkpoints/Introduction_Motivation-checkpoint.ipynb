# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit;">
#
# <h1 style="direction: rtl !important; text-align: right !important; font-family: inherit; font-size: 2em; font-weight: bold; color: #2c3e50;">הצעת פרויקט - סדנה במדעי הנתונים</h1>
# <hr style="border: 1px solid #3498db; width: 100%;">
#
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit;"><b>סמסטר:</b> 2026ג.</p>
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit;"><b>מגישים:</b> מקסים ואסתר.</p>
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit;"><b>מנחה:</b> ד"ר זאב קליוזנר.</p>
#
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit;">
#
# <h2 style="direction: rtl !important; text-align: right !important; font-family: inherit; font-size: 1.5em; font-weight: bold; color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 5px;">רעיון הפרויקט</h2>
#
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit; line-height: 1.6;">
# זיהוי וחילוץ נתוני מפתח בדרכון מתוך תמונות או קובצי PDF המכילים מסמכים שונים.
# </p>
#
# <h2 style="direction: rtl !important; text-align: right !important; font-family: inherit; font-size: 1.5em; font-weight: bold; color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 5px; margin-top: 25px;">מטרת הפרויקט</h2>
#
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit; line-height: 1.6;">פיתוח מערכת המבצעת את הפעולות הבאות:</p>
#
# <ul style="direction: rtl !important; text-align: right !important; font-family: inherit; list-style-type: square; padding-right: 20px; line-height: 1.6;">
#     <li style="direction: rtl !important; text-align: right !important; font-family: inherit; margin-bottom: 8px;"><b>זיהוי ואיתור:</b> זיהוי האם מופיע במסמך דרכון מלא ואיתור האזור המדויק שלו בתמונה.</li>
#     <li style="direction: rtl !important; text-align: right !important; font-family: inherit; margin-bottom: 8px;"><b>חילוץ נתוני מפתח:</b> שליפת שדות קריטיים כגון: <span style="color: #c0392b; font-weight: bold;">שם מלא, מספר דרכון, אזרחות, תאריך לידה ותאריך תפוגה</span>.</li>
#     <li style="direction: rtl !important; text-align: right !important; font-family: inherit; margin-bottom: 8px;"><b>עמידות ורובוסטיות:</b> התמודדות עם תנאים מאתגרים  כגון מסמכים המצולמים בזווית, חתוכים, חלקיים, באיכות נמוכה, או כאלה המכילים רעש ומידע נוסף ברקע.</li>
# </ul>
#
# </div>

# %% [markdown]
# <div style="direction: rtl !important; text-align: right !important; font-family: inherit;">
#
# <h2 style="direction: rtl !important; text-align: right !important; font-family: inherit; font-size: 1.5em; font-weight: bold; color: #2c3e50; border-bottom: 2px solid #3498db; padding-bottom: 5px;">מוטיבציה עסקית וטכנולוגית</h2>
#
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit; line-height: 1.6;">
# במציאות העסקית של היום, ארגונים, חברות ואנשים פרטיים מעבירים ומחליפים מדי יום אלפי מסמכים מזהים <b>המכילים פרטים אישיים ורגישים</b>. בחלק ניכר מהמקרים, תהליך הבדיקה, אימות הזהויות ושליפת הנתונים מתוך המסמכים הללו עדיין נעשה באופן ידני על ידי צוותי תפעול.
# </p>
#
# <p style="direction: rtl !important; text-align: right !important; font-family: inherit; line-height: 1.6;">
# תהליך ידני זה הוא איטי, מעכב את הלקוחות, דורש משאבים ארגוניים רבים, מועד לטעויות אנוש, וחושף מידע רגיש לעיניים אנושיות שלא לצורך. מערכת אוטומטית וחכמה לזיהוי וחילוץ פרטי דרכון מתוך מסמכים  יכולה לשמש ביעילות עצומה ארגונים במגוון רחב של תחומים כגון <b>בנקאות ופיננסים, חברות ביטוח, תיירות ותעופה, ומערכות קליטת עובדים </b>שבהן נדרש אימות זהות מהיר, מדויק, תוך הבטחת הגנה טובה יותר על פרטיות הנתונים.
# </p>
#
# </div>
